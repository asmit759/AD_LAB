# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X = iris.data
y = iris.target

print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("\nFirst 100 samples:\n")

for i in range(100):
    print(f"Sample {i+1}: {X[i]} (class: {y[i]}, species: {iris.target_names[y[i]]})")
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
#
# First 100 samples:
#
# Sample 1: [5.1 3.5 1.4 0.2] (class: 0, species: setosa)
# Sample 2: [4.9 3.  1.4 0.2] (class: 0, species: setosa)
# Sample 3: [4.7 3.2 1.3 0.2] (class: 0, species: setosa)
# Sample 4: [4.6 3.1 1.5 0.2] (class: 0, species: setosa)
# Sample 5: [5.  3.6 1.4 0.2] (class: 0, species: setosa)
# Sample 6: [5.4 3.9 1.7 0.4] (class: 0, species: setosa)
# Sample 7: [4.6 3.4 1.4 0.3] (class: 0, species: setosa)
# Sample 8: [5.  3.4 1.5 0.2] (class: 0, species: setosa)
# Sample 9: [4.4 2.9 1.4 0.2] (class: 0, species: setosa)
# Sample 10: [4.9 3.1 1.5 0.1] (class: 0, species: setosa)
# Sample 11: [5.4 3.7 1.5 0.2] (class: 0, species: setosa)
# Sample 12: [4.8 3.4 1.6 0.2] (class: 0, species: setosa)
# Sample 13: [4.8 3.  1.4 0.1] (class: 0, species: setosa)
# Sample 14: [4.3 3.  1.1 0.1] (class: 0, species: setosa)
# ...

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target_names[iris.target]

print("\nDataFrame Head:")
#print(df.head())
df
# Out:
# DataFrame Head:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# ...

# %%
plt.hist(
    df["sepal width (cm)"],
    bins=15,                # more bins = more visible gaps
    edgecolor='black',      # outlines each bar -> creates gap effect
    linewidth=1,
    alpha=0.8
)

plt.xlabel("Sepal width (cm)")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal width With Gaps")
plt.show()

# %%
sns.scatterplot(
    x=df["sepal length (cm)"],
    y=df["sepal width (cm)"],
    hue=df["species"]
)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
plt.show()

sns.scatterplot(
    x=df["petal length (cm)"],
    y=df["petal width (cm)"],
    hue=df["species"]
)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.iloc[:, :4].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
